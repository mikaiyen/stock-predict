# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
pd.options.mode.chained_assignment = None

stock_data = pd.read_csv('df2330_12to22.csv')

stock_data['trend'] = np.where(stock_data.Close.shift(-5) > stock_data.Close, 1, 0)
print(stock_data.isnull().sum())

print(stock_data)
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# trend     0
# dtype: int64
#             Date   Open   High    Low  Close     Volume  trend
# 0     2012-01-02   75.0   75.4   74.7   75.0  14945.219      1
# 1     2012-01-03   75.5   75.9   75.2   75.7  21223.640      1
# 2     2012-01-04   76.1   76.1   75.5   75.8  34126.472      1
# 3     2012-01-05   76.0   76.0   75.3   76.0  28076.670      1
# 4     2012-01-06   75.9   75.9   74.9   75.6  30123.118      1
# ...          ...    ...    ...    ...    ...        ...    ...
# 2697  2022-12-26  454.0  457.0  453.5  456.5   9152.790      0
# 2698  2022-12-27  458.0  462.5  457.0  457.0  10486.219      0
# 2699  2022-12-28  451.0  452.0  446.0  451.0  34823.492      0
# 2700  2022-12-29  444.0  449.5  442.5  446.0  25596.357      0
# 2701  2022-12-30  455.0  456.5  448.5  448.5  22297.604      0
#
# [2702 rows x 7 columns]

# %%
# define the target and features
target = ['Close']
features = ['Volume', 'High', 'Low']

# %%
df = stock_data[features + target]
df
# Out:
#          Volume   High    Low  Close
# 0     14945.219   75.4   74.7   75.0
# 1     21223.640   75.9   75.2   75.7
# 2     34126.472   76.1   75.5   75.8
# 3     28076.670   76.0   75.3   76.0
# 4     30123.118   75.9   74.9   75.6
# ...         ...    ...    ...    ...
# 2697   9152.790  457.0  453.5  456.5
# 2698  10486.219  462.5  457.0  457.0
# 2699  34823.492  452.0  446.0  451.0
# 2700  25596.357  449.5  442.5  446.0
# 2701  22297.604  456.5  448.5  448.5
#
# [2702 rows x 4 columns]

# %%
# split the data
split = int(df.shape[0] * 0.8)
df_train = df.iloc[:split, :].copy()
df_test = df.iloc[split:, :].copy()

# %%
df_train
# Out:
#          Volume   High    Low  Close
# 0     14945.219   75.4   74.7   75.0
# 1     21223.640   75.9   75.2   75.7
# 2     34126.472   76.1   75.5   75.8
# 3     28076.670   76.0   75.3   76.0
# 4     30123.118   75.9   74.9   75.6
# ...         ...    ...    ...    ...
# 2156  49987.278  456.5  450.0  453.0
# 2157  48274.801  456.0  448.5  449.0
# 2158  34846.906  457.5  451.0  457.5
# 2159  26567.638  457.0  451.0  451.0
# 2160  29906.921  456.0  451.0  453.0
#
# [2161 rows x 4 columns]

# %%
df_test
# Out:
#          Volume   High    Low  Close
# 2161  25285.547  455.0  449.5  455.0
# 2162  18777.385  458.0  451.5  452.0
# 2163  15800.622  455.0  450.0  450.0
# 2164  31795.010  448.5  445.5  447.0
# 2165  26221.663  447.0  443.0  444.0
# ...         ...    ...    ...    ...
# 2697   9152.790  457.0  453.5  456.5
# 2698  10486.219  462.5  457.0  457.0
# 2699  34823.492  452.0  446.0  451.0
# 2700  25596.357  449.5  442.5  446.0
# 2701  22297.604  456.5  448.5  448.5
#
# [541 rows x 4 columns]

# %%
# scale the data
target_scaler = MinMaxScaler().fit(df_train[target])
df_train[target] = target_scaler.transform(df_train[target])
df_test[target] = target_scaler.transform(df_test[target])

features_scaler = MinMaxScaler().fit(df_train[features])
df_train[features] = features_scaler.transform(df_train[features])
df_test[features] = features_scaler.transform(df_test[features])

# %%
# extract the input sequences and output values
sequence_length = 30

X_train, y_train = [], []

for i in range(sequence_length, df_train.shape[0]):
    X_train.append(df_train[features + target].iloc[i - sequence_length: i])
    y_train.append(df_train[target].iloc[i])

X_train, y_train = np.array(X_train), np.array(y_train)

X_test, y_test = [], []

for i in range(sequence_length, df_test.shape[0]):
    X_test.append(df_test[features + target].iloc[i - sequence_length: i])
    y_test.append(df_test[target].iloc[i])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_train.shape)

print(X_test.shape)
# Out:
# (2131, 30, 4)
# (511, 30, 4)

# %%
X_train
# Out:
# array([[[0.07859449, 0.00153178, 0.00234558, 0.00180552],
#         [0.11539163, 0.00280827, 0.00364868, 0.00361104],
#         [0.19101372, 0.00331887, 0.00443054, 0.00386897],
#         ...,
#         [0.34211068, 0.01046719, 0.01094605, 0.01083312],
#         [0.45389323, 0.01608374, 0.01459474, 0.01470209],
#         [0.17744141, 0.01531785, 0.0153766 , 0.01470209]],
#
#        [[0.11539163, 0.00280827, 0.00364868, 0.00361104],
#         [0.19101372, 0.00331887, 0.00443054, 0.00386897],
#         [0.15555649, 0.00306357, 0.0039093 , 0.00438483],
#         ...,
#         [0.45389323, 0.01608374, 0.01459474, 0.01470209],
#         [0.17744141, 0.01531785, 0.0153766 , 0.01470209],
#         [0.155916  , 0.01327547, 0.01433412, 0.01470209]],
#
#        [[0.19101372, 0.00331887, 0.00443054, 0.00386897],
#         [0.15555649, 0.00306357, 0.0039093 , 0.00438483],
#         [0.1675505 , 0.00280827, 0.00286682, 0.00335311],
#         ...,
#         [0.17744141, 0.01531785, 0.0153766 , 0.01470209],
#         [0.155916  , 0.01327547, 0.01433412, 0.01470209],
#         [0.23213562, 0.01327547, 0.01355225, 0.0139283 ]],
#
#        ...,
#
#        [[0.23723819, 0.93489916, 0.92963253, 0.9251999 ],
#         [0.22944444, 0.9310697 , 0.93745113, 0.93293784],
#         [0.29195842, 0.91319888, 0.92051082, 0.91488264],
#         ...,
#         [0.29973776, 0.98595864, 0.9986969 , 0.99226206],
#         [0.28397218, 0.97447026, 0.98045348, 0.97678617],
#         [0.27393554, 0.97319377, 0.97654418, 0.96646892]],
#
#        [[0.22944444, 0.9310697 , 0.93745113, 0.93293784],
#         [0.29195842, 0.91319888, 0.92051082, 0.91488264],
#         [0.22458556, 0.91319888, 0.91529841, 0.9071447 ],
#         ...,
#         [0.28397218, 0.97447026, 0.98045348, 0.97678617],
#         [0.27393554, 0.97319377, 0.97654418, 0.96646892],
#         [0.19523611, 0.97702323, 0.98305968, 0.98839309]],
#
#        [[0.29195842, 0.91319888, 0.92051082, 0.91488264],
#         [0.22458556, 0.91319888, 0.91529841, 0.9071447 ],
#         [0.12999128, 0.91447536, 0.92181392, 0.92004127],
#         ...,
#         [0.27393554, 0.97319377, 0.97654418, 0.96646892],
#         [0.19523611, 0.97702323, 0.98305968, 0.98839309],
#         [0.14671222, 0.97574674, 0.98305968, 0.97162755]]])

# %%
# build and train the model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=X_train.shape[1:]))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X_train, y_train, epochs=32, batch_size=64)

model.evaluate(X_test, y_test)

#save the model
model.save('multi_intput_LSTM_model_eps32_bsize64.h5')

# generate the test set predictions
y_pred = model.predict(X_test)
y_pred = target_scaler.inverse_transform(y_pred)
# Out:
# Epoch 1/32
# 34/34 [==============================] - 8s 67ms/step - loss: 0.0148
# Epoch 2/32
# 34/34 [==============================] - 2s 63ms/step - loss: 0.0031
# Epoch 3/32
# 34/34 [==============================] - 2s 67ms/step - loss: 0.0027
# Epoch 4/32
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0023
# Epoch 5/32
# 34/34 [==============================] - 2s 71ms/step - loss: 0.0023
# Epoch 6/32
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0023
# Epoch 7/32
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0022
# Epoch 8/32
# 34/34 [==============================] - 2s 69ms/step - loss: 0.0021
# Epoch 9/32
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0019
# Epoch 10/32
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0019
# Epoch 11/32
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0019
# Epoch 12/32
# 34/34 [==============================] - 2s 69ms/step - loss: 0.0018
# Epoch 13/32
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0020
# Epoch 14/32
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0018
# Epoch 15/32
# 34/34 [==============================] - 2s 67ms/step - loss: 0.0016
# Epoch 16/32
# 34/34 [==============================] - 2s 71ms/step - loss: 0.0021
# Epoch 17/32
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0017
# Epoch 18/32
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0016
# Epoch 19/32
# 34/34 [==============================] - 2s 71ms/step - loss: 0.0017
# Epoch 20/32
# 34/34 [==============================] - 3s 76ms/step - loss: 0.0016
# Epoch 21/32
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0016
# Epoch 22/32
# 34/34 [==============================] - 2s 69ms/step - loss: 0.0015
# Epoch 23/32
# 34/34 [==============================] - 2s 69ms/step - loss: 0.0013
# Epoch 24/32
# 34/34 [==============================] - 2s 70ms/step - loss: 0.0015
# Epoch 25/32
# 34/34 [==============================] - 2s 69ms/step - loss: 0.0015
# Epoch 26/32
# 34/34 [==============================] - 2s 71ms/step - loss: 0.0013
# Epoch 27/32
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0014
# Epoch 28/32
# 34/34 [==============================] - 2s 69ms/step - loss: 0.0013
# Epoch 29/32
# 34/34 [==============================] - 2s 73ms/step - loss: 0.0013
# Epoch 30/32
# 34/34 [==============================] - 2s 72ms/step - loss: 0.0014
# Epoch 31/32
# 34/34 [==============================] - 2s 71ms/step - loss: 0.0012
# Epoch 32/32
# 34/34 [==============================] - 3s 76ms/step - loss: 0.0012
# 16/16 [==============================] - 1s 13ms/step - loss: 0.0080
# 16/16 [==============================] - 2s 14ms/step

# %%
# plot the test set predictions
df['Predicted Close'] = np.nan
df['Predicted Close'].iloc[- y_pred.shape[0]:] = y_pred.flatten()
plot=df[['Close', 'Predicted Close']].plot()
fig = plot.get_figure()
fig.savefig("multi_intput_LSTM_model_eps32_bsize64.png")

# %%
res=pd.concat([stock_data['Date'],df],axis=1)
res
# Out:
#             Date     Volume   High    Low  Close  Predicted Close
# 0     2012-01-02  14945.219   75.4   74.7   75.0              NaN
# 1     2012-01-03  21223.640   75.9   75.2   75.7              NaN
# 2     2012-01-04  34126.472   76.1   75.5   75.8              NaN
# 3     2012-01-05  28076.670   76.0   75.3   76.0              NaN
# 4     2012-01-06  30123.118   75.9   74.9   75.6              NaN
# ...          ...        ...    ...    ...    ...              ...
# 2697  2022-12-26   9152.790  457.0  453.5  456.5       474.283295
# 2698  2022-12-27  10486.219  462.5  457.0  457.0       472.363281
# 2699  2022-12-28  34823.492  452.0  446.0  451.0       470.571564
# 2700  2022-12-29  25596.357  449.5  442.5  446.0       468.703827
# 2701  2022-12-30  22297.604  456.5  448.5  448.5       466.753235
#
# [2702 rows x 6 columns]

# %%
dfpred=res[['Date','Close', 'Predicted Close']].dropna()
dfpred
# Out:
#             Date  Close  Predicted Close
# 2191  2020-12-03  497.0       496.867676
# 2192  2020-12-04  503.0       497.642975
# 2193  2020-12-07  514.0       497.805695
# 2194  2020-12-08  524.0       497.715027
# 2195  2020-12-09  520.0       497.770630
# ...          ...    ...              ...
# 2697  2022-12-26  456.5       474.283295
# 2698  2022-12-27  457.0       472.363281
# 2699  2022-12-28  451.0       470.571564
# 2700  2022-12-29  446.0       468.703827
# 2701  2022-12-30  448.5       466.753235
#
# [511 rows x 3 columns]

# %%
dfpred.plot(x='Date')
# Out:
# <AxesSubplot: xlabel='Date'>
