# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
pd.options.mode.chained_assignment = None

stock_data = pd.read_csv('dfnew_proc_v3.csv')

print(stock_data.isnull().sum())

print(stock_data)
# Out:
# DateTime        0
# Date            0
# Volume          0
# Transaction     0
# Value           0
# Open            0
# High            0
# Low             0
# Dir             0
# Change          0
# ForeignBuy      0
# ForeignSell     0
# ForeignNet      0
# TrustBuy        0
# TrustSell       0
# TrustNet        0
# DealerNet       0
# DealerBuy       0
# DealerSell      0
# InvestorsNet    0
# PE-Ratio        0
# PBR             0
# Yield           0
# Close           0
# Pattern         0
# dtype: int64
#         DateTime      Date    Volume  Transaction        Value   Open   High  \
# 0       2013/1/2  20130102  40647121        14353   4021304950   97.6   99.9
# 1       2013/1/3  20130103  44335846        12616   4472175100  100.5  102.0
# 2       2013/1/4  20130104  39502577        10276   3980403777  100.5  101.5
# 3       2013/1/7  20130107  42328657         9042   4237769552  101.0  101.0
# 4       2013/1/8  20130108  31218717         9463   3100841808   99.6  100.0
# ...          ...       ...       ...          ...          ...    ...    ...
# 2447  2022/12/26  20221226   9152790        16718   4171194858  454.0  457.0
# 2448  2022/12/27  20221227  10486219        13482   4820155221  458.0  462.5
# 2449  2022/12/28  20221228  34823492        59400  15643266841  451.0  452.0
# 2450  2022/12/29  20221229  25596357        34637  11400284554  444.0  449.5
# 2451  2022/12/30  20221230  22297604        23086  10079102379  455.0  456.5
#
#         Low Dir  Change  ...  TrustNet  DealerNet  DealerBuy  DealerSell  \
# 0      97.1   +     2.6  ...   1599000    -350000    1300000     1650000
# 1     100.0   +     1.4  ...    410000   -1067000    1512000     2579000
# 2     100.0   +     0.5  ...     44000    -246000     910000     1156000
# 3      99.1   -     1.0  ...   -722000    -450000     871000     1321000
# 4      98.9   -     0.8  ...   -426000     -80000     749000      829000
# ...     ...  ..     ...  ...       ...        ...        ...         ...
# 2447  453.5   +     1.5  ...    -69028     -62155     406949      469104
# 2448  457.0   +     0.5  ...     61230     -61970     224188      286158
# 2449  446.0   -     6.0  ...    -59000   -1739234     673000     2412234
# 2450  442.5   -     5.0  ...   -123700    1168332    1414000      245668
# 2451  448.5   +     2.5  ...   -242000     539790     892394      352604
#
#       InvestorsNet  PE-Ratio   PBR  Yield  Close        Pattern
# 0         15108173     16.54  3.83   3.01   99.6           None
# 1         14298188     16.78  3.88   2.97  101.0           None
# 2          9042611     16.86  3.90   2.96  101.5           None
# 3         -1511300     16.69  3.86   2.99  100.5           None
# 4          1034826     16.56  3.83   3.01   99.7           None
# ...            ...       ...   ...    ...    ...            ...
# 2447      -1168837     13.35  4.32   2.41  456.5  Piercing Line
# 2448        753909     13.36  4.33   2.41  457.0           None
# 2449     -17427683     13.19  4.27   2.44  451.0           None
# 2450      -4854205     13.04  4.22   2.47  446.0           None
# 2451        132141     13.11  4.25   2.45  448.5           None
#
# [2452 rows x 25 columns]

# %%
# define the target and features
target = ['Close']
features = ['Volume', 'High', 'Low','ForeignNet','TrustNet','DealerNet','PE-Ratio']

# %%
df = stock_data[features + target]
df
# Out:
#         Volume   High    Low  ForeignNet  TrustNet  DealerNet  PE-Ratio  Close
# 0     40647121   99.9   97.1  13859173.0   1599000    -350000     16.54   99.6
# 1     44335846  102.0  100.0  14955188.0    410000   -1067000     16.78  101.0
# 2     39502577  101.5  100.0   9244611.0     44000    -246000     16.86  101.5
# 3     42328657  101.0   99.1   -339300.0   -722000    -450000     16.69  100.5
# 4     31218717  100.0   98.9   1540826.0   -426000     -80000     16.56   99.7
# ...        ...    ...    ...         ...       ...        ...       ...    ...
# 2447   9152790  457.0  453.5  -1037654.0    -69028     -62155     13.35  456.5
# 2448  10486219  462.5  457.0    754649.0     61230     -61970     13.36  457.0
# 2449  34823492  452.0  446.0 -15629449.0    -59000   -1739234     13.19  451.0
# 2450  25596357  449.5  442.5  -5898837.0   -123700    1168332     13.04  446.0
# 2451  22297604  456.5  448.5   -165649.0   -242000     539790     13.11  448.5
#
# [2452 rows x 8 columns]

# %%
# split the data
split = int(df.shape[0] * 0.8)
df_train = df.iloc[:split, :].copy()
df_test = df.iloc[split:, :].copy()

# %%
df_train
# Out:
#         Volume   High    Low  ForeignNet  TrustNet  DealerNet  PE-Ratio  Close
# 0     40647121   99.9   97.1  13859173.0   1599000    -350000     16.54   99.6
# 1     44335846  102.0  100.0  14955188.0    410000   -1067000     16.78  101.0
# 2     39502577  101.5  100.0   9244611.0     44000    -246000     16.86  101.5
# 3     42328657  101.0   99.1   -339300.0   -722000    -450000     16.69  100.5
# 4     31218717  100.0   98.9   1540826.0   -426000     -80000     16.56   99.7
# ...        ...    ...    ...         ...       ...        ...       ...    ...
# 1956  15218008  512.0  508.0   2236412.0     25970     266765     26.93  510.0
# 1957  12581145  515.0  510.0   3490555.0   -420000     578690     26.98  511.0
# 1958  39978821  485.5  475.0   5428881.0     26000     557170     27.19  475.0
# 1959  20226736  517.0  513.0   4252779.0    -88180   -1276000     27.19  515.0
# 1960  46705107  525.0  514.0  15638945.0    257000    2340998     27.72  525.0
#
# [1961 rows x 8 columns]

# %%
df_test
# Out:
#         Volume   High    Low  ForeignNet  TrustNet  DealerNet  PE-Ratio  Close
# 1961  31173332  530.0  524.0   4607817.0    419000     145827     27.98  530.0
# 1962  39489959  540.0  528.0  12463306.0    -32890     865012     28.30  536.0
# 1963  34839391  542.0  535.0   3016404.0    178430    -450512     28.62  542.0
# 1964  55614434  555.0  541.0   5149667.0    105000   -4162805     28.99  549.0
# 1965  53392763  570.0  553.0   1499379.0    -75040    2060204     29.83  565.0
# ...        ...    ...    ...         ...       ...        ...       ...    ...
# 2447   9152790  457.0  453.5  -1037654.0    -69028     -62155     13.35  456.5
# 2448  10486219  462.5  457.0    754649.0     61230     -61970     13.36  457.0
# 2449  34823492  452.0  446.0 -15629449.0    -59000   -1739234     13.19  451.0
# 2450  25596357  449.5  442.5  -5898837.0   -123700    1168332     13.04  446.0
# 2451  22297604  456.5  448.5   -165649.0   -242000     539790     13.11  448.5
#
# [491 rows x 8 columns]

# %%
# scale the data
target_scaler = MinMaxScaler().fit(df_train[target])
df_train[target] = target_scaler.transform(df_train[target])
df_test[target] = target_scaler.transform(df_test[target])

features_scaler = MinMaxScaler().fit(df_train[features])
df_train[features] = features_scaler.transform(df_train[features])
df_test[features] = features_scaler.transform(df_test[features])

# %%
df_train
# Out:
#         Volume      High       Low  ForeignNet  TrustNet  DealerNet  PE-Ratio  \
# 0     0.229231  0.011625  0.009834    0.585105  0.644491   0.424735  0.378075
# 1     0.250850  0.016508  0.016624    0.591171  0.513095   0.382689  0.390909
# 2     0.222522  0.015345  0.016624    0.559563  0.472649   0.430833  0.395187
# 3     0.239086  0.014183  0.014517    0.506515  0.387999   0.418871  0.386096
# 4     0.173972  0.011858  0.014048    0.516922  0.420709   0.440568  0.379144
# ...        ...       ...       ...         ...       ...        ...       ...
# 1956  0.080193  0.969774  0.971904    0.520772  0.470656   0.460902  0.933690
# 1957  0.064739  0.976750  0.976586    0.527714  0.421373   0.479194  0.936364
# 1958  0.225314  0.908161  0.894638    0.538442  0.470660   0.477932  0.947594
# 1959  0.109549  0.981400  0.983610    0.531933  0.458042   0.370433  0.947594
# 1960  0.264736  1.000000  0.985952    0.594956  0.496187   0.582537  0.975936
#
#          Close
# 0     0.012076
# 1     0.015327
# 2     0.016489
# 3     0.014166
# 4     0.012308
# ...        ...
# 1956  0.965165
# 1957  0.967487
# 1958  0.883883
# 1959  0.976777
# 1960  1.000000
#
# [1961 rows x 8 columns]

# %%
# extract the input sequences and output values
sequence_length = 10

X_train, y_train = [], []

for i in range(sequence_length, df_train.shape[0]):
    X_train.append(df_train[features + target].iloc[i - sequence_length: i])
    y_train.append(df_train[target].iloc[i])

X_train, y_train = np.array(X_train), np.array(y_train)

X_test, y_test = [], []

for i in range(sequence_length, df_test.shape[0]):
    X_test.append(df_test[features + target].iloc[i - sequence_length: i])
    y_test.append(df_test[target].iloc[i])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_train.shape)

print(X_test.shape)
# Out:
# (1951, 10, 8)
# (481, 10, 8)

# %%
X_train
# Out:
# array([[[0.22923054, 0.0116252 , 0.00983376, ..., 0.42473465,
#          0.37807487, 0.01207617],
#         [0.25084975, 0.01650779, 0.01662374, ..., 0.38268926,
#          0.39090909, 0.01532745],
#         [0.22252249, 0.01534527, 0.01662374, ..., 0.43083328,
#          0.39518717, 0.01648862],
#         ...,
#         [0.12576664, 0.01534527, 0.01779443, ..., 0.44121269,
#          0.39090909, 0.01532745],
#         [0.12917778, 0.01650779, 0.01662374, ..., 0.44332376,
#          0.39946524, 0.01764979],
#         [0.20208292, 0.01650779, 0.01615547, ..., 0.4304228 ,
#          0.38609626, 0.01416628]],
#
#        [[0.25084975, 0.01650779, 0.01662374, ..., 0.38268926,
#          0.39090909, 0.01532745],
#         [0.22252249, 0.01534527, 0.01662374, ..., 0.43083328,
#          0.39518717, 0.01648862],
#         [0.23908584, 0.01418275, 0.01451651, ..., 0.41887058,
#          0.38609626, 0.01416628],
#         ...,
#         [0.12917778, 0.01650779, 0.01662374, ..., 0.44332376,
#          0.39946524, 0.01764979],
#         [0.20208292, 0.01650779, 0.01615547, ..., 0.4304228 ,
#          0.38609626, 0.01416628],
#         [0.19904248, 0.01302023, 0.01475064, ..., 0.49434117,
#          0.37486631, 0.01114724]],
#
#        [[0.22252249, 0.01534527, 0.01662374, ..., 0.43083328,
#          0.39518717, 0.01648862],
#         [0.23908584, 0.01418275, 0.01451651, ..., 0.41887058,
#          0.38609626, 0.01416628],
#         [0.17397169, 0.01185771, 0.01404823, ..., 0.44056764,
#          0.37914439, 0.01230841],
#         ...,
#         [0.20208292, 0.01650779, 0.01615547, ..., 0.4304228 ,
#          0.38609626, 0.01416628],
#         [0.19904248, 0.01302023, 0.01475064, ..., 0.49434117,
#          0.37486631, 0.01114724],
#         [0.22852238, 0.01418275, 0.01311168, ..., 0.40450361,
#          0.37593583, 0.01137947]],
#
#        ...,
#
#        [[0.17157476, 0.97209951, 0.97190354, ..., 0.42085539,
#          0.92780749, 0.9605202 ],
#         [0.24337157, 0.96512439, 0.96253805, ..., 0.40889609,
#          0.91657754, 0.95123084],
#         [0.30550512, 0.97674959, 0.96956216, ..., 0.43616959,
#          0.93903743, 0.96980957],
#         ...,
#         [0.09837869, 0.96744943, 0.96722079, ..., 0.45552102,
#          0.93048128, 0.96284255],
#         [0.08019327, 0.96977447, 0.97190354, ..., 0.46090219,
#          0.93368984, 0.96516489],
#         [0.06473891, 0.97674959, 0.97658628, ..., 0.47919369,
#          0.93636364, 0.96748723]],
#
#        [[0.24337157, 0.96512439, 0.96253805, ..., 0.40889609,
#          0.91657754, 0.95123084],
#         [0.30550512, 0.97674959, 0.96956216, ..., 0.43616959,
#          0.93903743, 0.96980957],
#         [0.2212519 , 0.97674959, 0.97190354, ..., 0.43131572,
#          0.92780749, 0.9605202 ],
#         ...,
#         [0.08019327, 0.96977447, 0.97190354, ..., 0.46090219,
#          0.93368984, 0.96516489],
#         [0.06473891, 0.97674959, 0.97658628, ..., 0.47919369,
#          0.93636364, 0.96748723],
#         [0.2253137 , 0.90816089, 0.89463826, ..., 0.47793174,
#          0.94759358, 0.88388295]],
#
#        [[0.30550512, 0.97674959, 0.96956216, ..., 0.43616959,
#          0.93903743, 0.96980957],
#         [0.2212519 , 0.97674959, 0.97190354, ..., 0.43131572,
#          0.92780749, 0.9605202 ],
#         [0.22910383, 0.96977447, 0.96956216, ..., 0.40431736,
#          0.93368984, 0.96516489],
#         ...,
#         [0.06473891, 0.97674959, 0.97658628, ..., 0.47919369,
#          0.93636364, 0.96748723],
#         [0.2253137 , 0.90816089, 0.89463826, ..., 0.47793174,
#          0.94759358, 0.88388295],
#         [0.10954888, 0.98139967, 0.9836104 , ..., 0.37043335,
#          0.94759358, 0.97677659]]])

# %%
X_test
# Out:
# array([[[0.17370569, 1.0116252 , 1.00936549, ..., 0.4538103 ,
#          0.98983957, 1.0116117 ],
#         [0.22244854, 1.03487561, 1.01873098, ..., 0.49598382,
#          1.00695187, 1.02554575],
#         [0.19519206, 1.03952569, 1.03512058, ..., 0.41884056,
#          1.02406417, 1.0394798 ],
#         ...,
#         [0.29931561, 1.16740293, 1.14516507, ..., 0.49018009,
#          1.16203209, 1.1532745 ],
#         [0.43471666, 1.18600326, 1.17092016, ..., 0.55968   ,
#          1.20160428, 1.18578727],
#         [0.52029756, 1.16740293, 1.15687193, ..., 0.44263279,
#          1.16524064, 1.15559684]],
#
#        [[0.22244854, 1.03487561, 1.01873098, ..., 0.49598382,
#          1.00695187, 1.02554575],
#         [0.19519206, 1.03952569, 1.03512058, ..., 0.41884056,
#          1.02406417, 1.0394798 ],
#         [0.31695233, 1.06975122, 1.04916881, ..., 0.20114906,
#          1.04385027, 1.05573618],
#         ...,
#         [0.43471666, 1.18600326, 1.17092016, ..., 0.55968   ,
#          1.20160428, 1.18578727],
#         [0.52029756, 1.16740293, 1.15687193, ..., 0.44263279,
#          1.16524064, 1.15559684],
#         [0.58294164, 1.23250407, 1.18965114, ..., 0.46937923,
#          1.19037433, 1.17649791]],
#
#        [[0.19519206, 1.03952569, 1.03512058, ..., 0.41884056,
#          1.02406417, 1.0394798 ],
#         [0.31695233, 1.06975122, 1.04916881, ..., 0.20114906,
#          1.04385027, 1.05573618],
#         [0.30393136, 1.10462683, 1.07726528, ..., 0.56607072,
#          1.08877005, 1.09289364],
#         ...,
#         [0.52029756, 1.16740293, 1.15687193, ..., 0.44263279,
#          1.16524064, 1.15559684],
#         [0.58294164, 1.23250407, 1.18965114, ..., 0.46937923,
#          1.19037433, 1.17649791],
#         [0.28632466, 1.19297838, 1.17326153, ..., 0.47569571,
#          1.20748663, 1.19043196]],
#
#        ...,
#
#        [[0.19767937, 0.89653569, 0.88761414, ..., 0.42753052,
#          0.24491979, 0.89665583],
#         [0.14339565, 0.89886073, 0.89346757, ..., 0.42068053,
#          0.24491979, 0.89665583],
#         [0.29405535, 0.8744478 , 0.87239522, ..., 0.26566293,
#          0.22994652, 0.87459359],
#         ...,
#         [0.14762954, 0.84538479, 0.84781082, ..., 0.40552853,
#          0.20481283, 0.83743614],
#         [0.04464569, 0.84189723, 0.84429876, ..., 0.44161409,
#          0.20748663, 0.84091965],
#         [0.05246077, 0.85468496, 0.85249356, ..., 0.44162493,
#          0.20802139, 0.84208082]],
#
#        [[0.14339565, 0.89886073, 0.89346757, ..., 0.42068053,
#          0.24491979, 0.89665583],
#         [0.29405535, 0.8744478 , 0.87239522, ..., 0.26566293,
#          0.22994652, 0.87459359],
#         [0.13302127, 0.87096024, 0.87122454, ..., 0.38220706,
#          0.22299465, 0.86414306],
#         ...,
#         [0.04464569, 0.84189723, 0.84429876, ..., 0.44161409,
#          0.20748663, 0.84091965],
#         [0.05246077, 0.85468496, 0.85249356, ..., 0.44162493,
#          0.20802139, 0.84208082],
#         [0.19509888, 0.83027203, 0.82673847, ..., 0.34326898,
#          0.19893048, 0.82814677]],
#
#        [[0.29405535, 0.8744478 , 0.87239522, ..., 0.26566293,
#          0.22994652, 0.87459359],
#         [0.13302127, 0.87096024, 0.87122454, ..., 0.38220706,
#          0.22299465, 0.86414306],
#         [0.18547454, 0.86514764, 0.84781082, ..., 0.37188753,
#          0.20909091, 0.84324199],
#         ...,
#         [0.05246077, 0.85468496, 0.85249356, ..., 0.44162493,
#          0.20802139, 0.84208082],
#         [0.19509888, 0.83027203, 0.82673847, ..., 0.34326898,
#          0.19893048, 0.82814677],
#         [0.14101965, 0.82445943, 0.81854367, ..., 0.51377071,
#          0.19090909, 0.81653507]]])

# %%
# build and train the model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=X_train.shape[1:]))
model.add(Dropout(0.2))
model.add(LSTM(units=100, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=200, return_sequences=False))
model.add(Dropout(0.2))
# model.add(LSTM(units=20, return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(units=60, return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(units=120, return_sequences=True))
# model.add(Dropout(0.2))
model.add(Dense(units=100))
model.add(Dense(units=25))
model.add(Dense(units=1))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 10, 50)            11800
#
#  dropout_2 (Dropout)         (None, 10, 50)            0
#
#  lstm_3 (LSTM)               (None, 10, 100)           60400
#
#  dropout_3 (Dropout)         (None, 10, 100)           0
#
#  lstm_4 (LSTM)               (None, 200)               240800
#
#  dropout_4 (Dropout)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 100)               20100
#
#  dense_3 (Dense)             (None, 25)                2525
#
#  dense_4 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 335,651
# Trainable params: 335,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

train_history=model.fit(X_train, y_train, epochs=50, batch_size=64)

model.evaluate(X_test, y_test)

#save the model
model.save('multi_intput_LSTM_model_eps50_bsize64.h5')

# generate the test set predictions
y_pred = model.predict(X_test)
y_pred = target_scaler.inverse_transform(y_pred)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 4s 28ms/step - loss: 0.0130
# Epoch 2/50
# 31/31 [==============================] - 1s 28ms/step - loss: 0.0011
# Epoch 3/50
# 31/31 [==============================] - 1s 29ms/step - loss: 8.7394e-04
# Epoch 4/50
# 31/31 [==============================] - 1s 29ms/step - loss: 8.7823e-04
# Epoch 5/50
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0011
# Epoch 6/50
# 31/31 [==============================] - 1s 28ms/step - loss: 7.2863e-04
# Epoch 7/50
# 31/31 [==============================] - 1s 28ms/step - loss: 7.4589e-04
# Epoch 8/50
# 31/31 [==============================] - 1s 28ms/step - loss: 7.3625e-04
# Epoch 9/50
# 31/31 [==============================] - 1s 29ms/step - loss: 7.3601e-04
# Epoch 10/50
# 31/31 [==============================] - 1s 29ms/step - loss: 7.4090e-04
# Epoch 11/50
# 31/31 [==============================] - 1s 30ms/step - loss: 7.0572e-04
# Epoch 12/50
# 31/31 [==============================] - 1s 29ms/step - loss: 6.6386e-04
# Epoch 13/50
# 31/31 [==============================] - 1s 29ms/step - loss: 6.0794e-04
# Epoch 14/50
# 31/31 [==============================] - 1s 28ms/step - loss: 6.2881e-04
# Epoch 15/50
# 31/31 [==============================] - 1s 29ms/step - loss: 6.1417e-04
# Epoch 16/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.2458e-04
# Epoch 17/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.4753e-04
# Epoch 18/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.9645e-04
# Epoch 19/50
# 31/31 [==============================] - 1s 29ms/step - loss: 8.7304e-04
# Epoch 20/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.9015e-04
# Epoch 21/50
# 31/31 [==============================] - 1s 30ms/step - loss: 5.7199e-04
# Epoch 22/50
# 31/31 [==============================] - 1s 30ms/step - loss: 7.0656e-04
# Epoch 23/50
# 31/31 [==============================] - 1s 30ms/step - loss: 4.9982e-04
# Epoch 24/50
# 31/31 [==============================] - 1s 30ms/step - loss: 5.4185e-04
# Epoch 25/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.7911e-04
# Epoch 26/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.8573e-04
# Epoch 27/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.2527e-04
# Epoch 28/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.9990e-04
# Epoch 29/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.0719e-04
# Epoch 30/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.6990e-04
# Epoch 31/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.7427e-04
# Epoch 32/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.5546e-04
# Epoch 33/50
# 31/31 [==============================] - 1s 28ms/step - loss: 7.8756e-04
# Epoch 34/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.7288e-04
# Epoch 35/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.0273e-04
# Epoch 36/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.6702e-04
# Epoch 37/50
# 31/31 [==============================] - 1s 29ms/step - loss: 6.0046e-04
# Epoch 38/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.8883e-04
# Epoch 39/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.4489e-04
# Epoch 40/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.9837e-04
# Epoch 41/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.7768e-04
# Epoch 42/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.5576e-04
# Epoch 43/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.5589e-04
# Epoch 44/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.4958e-04
# Epoch 45/50
# 31/31 [==============================] - 1s 28ms/step - loss: 3.9857e-04
# Epoch 46/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.5494e-04
# Epoch 47/50
# 31/31 [==============================] - 1s 28ms/step - loss: 6.9515e-04
# Epoch 48/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.7815e-04
# Epoch 49/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.5080e-04
# Epoch 50/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.4534e-04
# 16/16 [==============================] - 1s 6ms/step - loss: 0.0020
# 16/16 [==============================] - 1s 6ms/step

# %%
# import matplotlib.pyplot as plt
# train_history.history
# plt.plot(train_history.history["loss"])
# # plt.plot(train_history.history["val_loss"])
# plt.title("Train History")
# plt.ylabel("loss")
# plt.xlabel("Epoch")
# plt.legend(['train','validation'],loc='upper left')
# # plt.show()

# %%
# plot the test set predictions
df['Predicted Close'] = np.nan
df['Predicted Close'].iloc[- y_pred.shape[0]:] = y_pred.flatten()
plot=df[['Close', 'Predicted Close']].plot()
fig = plot.get_figure()
fig.savefig("multi_intput_LSTM_model_eps32_bsize64.png")

# %%
res=pd.concat([stock_data['DateTime'],df],axis=1)
res
# Out:
#         DateTime    Volume   High    Low  ForeignNet  TrustNet  DealerNet  \
# 0     2013-01-02  40647121   99.9   97.1  13859173.0   1599000    -350000
# 1     2013-01-03  44335846  102.0  100.0  14955188.0    410000   -1067000
# 2     2013-01-04  39502577  101.5  100.0   9244611.0     44000    -246000
# 3     2013-01-07  42328657  101.0   99.1   -339300.0   -722000    -450000
# 4     2013-01-08  31218717  100.0   98.9   1540826.0   -426000     -80000
# ...          ...       ...    ...    ...         ...       ...        ...
# 2447  2022-12-26   9152790  457.0  453.5  -1037654.0    -69028     -62155
# 2448  2022-12-27  10486219  462.5  457.0    754649.0     61230     -61970
# 2449  2022-12-28  34823492  452.0  446.0 -15629449.0    -59000   -1739234
# 2450  2022-12-29  25596357  449.5  442.5  -5898837.0   -123700    1168332
# 2451  2022-12-30  22297604  456.5  448.5   -165649.0   -242000     539790
#
#       PE-Ratio  Close  Predicted Close
# 0        16.54   99.6              NaN
# 1        16.78  101.0              NaN
# 2        16.86  101.5              NaN
# 3        16.69  100.5              NaN
# 4        16.56   99.7              NaN
# ...        ...    ...              ...
# 2447     13.35  456.5       482.293365
# 2448     13.36  457.0       479.389313
# 2449     13.19  451.0       476.544220
# 2450     13.04  446.0       473.559509
# 2451     13.11  448.5       470.176025
#
# [2452 rows x 10 columns]

# %%
dfpred=res[['DateTime','Close', 'Predicted Close']].dropna()
dfpred
# Out:
#         DateTime  Close  Predicted Close
# 1971  2021-01-15  601.0       567.835266
# 1972  2021-01-18  607.0       574.925842
# 1973  2021-01-19  627.0       580.772461
# 1974  2021-01-20  647.0       587.753174
# 1975  2021-01-21  673.0       596.471313
# ...          ...    ...              ...
# 2447  2022-12-26  456.5       482.293365
# 2448  2022-12-27  457.0       479.389313
# 2449  2022-12-28  451.0       476.544220
# 2450  2022-12-29  446.0       473.559509
# 2451  2022-12-30  448.5       470.176025
#
# [481 rows x 3 columns]

# %%
dfpred.plot(x='DateTime')
# Out:
# <AxesSubplot: xlabel='DateTime'>
