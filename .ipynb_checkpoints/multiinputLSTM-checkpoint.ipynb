# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
pd.options.mode.chained_assignment = None

stock_data = pd.read_csv('dfnew_proc.csv')

print(stock_data.isnull().sum())

print(stock_data)
# Out:
# DateTime     0
# Date         0
# 成交股數         0
# 成交筆數         0
# 成交金額         0
# 開盤價          0
# 最高價          0
# 最低價          0
# 收盤價          0
# 漲跌(+/-)      0
# 漲跌價差         0
# 外資買進股數       0
# 外資賣出股數       0
# 外資買賣超股數      0
# 投信買進股數       0
# 投信賣出股數       0
# 投信買賣超股數      0
# 自營商買賣超股數     0
# 自營商買進股數      0
# 自營商賣出股數      0
# 三大法人買賣超股數    0
# 本益比          0
# 股價淨值比        0
# 殖利率          0
# dtype: int64
#         DateTime      Date      成交股數   成交筆數         成交金額    開盤價    最高價    最低價  \
# 0     2013-01-02  20130102  40647121  14353   4021304950   97.6   99.9   97.1
# 1     2013-01-03  20130103  44335846  12616   4472175100  100.5  102.0  100.0
# 2     2013-01-04  20130104  39502577  10276   3980403777  100.5  101.5  100.0
# 3     2013-01-07  20130107  42328657   9042   4237769552  101.0  101.0   99.1
# 4     2013-01-08  20130108  31218717   9463   3100841808   99.6  100.0   98.9
# ...          ...       ...       ...    ...          ...    ...    ...    ...
# 2447  2022-12-26  20221226   9152790  16718   4171194858  454.0  457.0  453.5
# 2448  2022-12-27  20221227  10486219  13482   4820155221  458.0  462.5  457.0
# 2449  2022-12-28  20221228  34823492  59400  15643266841  451.0  452.0  446.0
# 2450  2022-12-29  20221229  25596357  34637  11400284554  444.0  449.5  442.5
# 2451  2022-12-30  20221230  22297604  23086  10079102379  455.0  456.5  448.5
#
#         收盤價 漲跌(+/-)  ...   投信買進股數  投信賣出股數  投信買賣超股數  自營商買賣超股數    自營商買進股數  \
# 0      99.6       +  ...  1746000  147000  1599000   -350000  1300000.0
# 1     101.0       +  ...   926000  516000   410000  -1067000  1512000.0
# 2     101.5       +  ...   234000  190000    44000   -246000   910000.0
# 3     100.5       -  ...   203000  925000  -722000   -450000   871000.0
# 4      99.7       -  ...   209000  635000  -426000    -80000   749000.0
# ...     ...     ...  ...      ...     ...      ...       ...        ...
# 2447  456.5       +  ...   225000  294028   -69028    -62155   406949.0
# 2448  457.0       +  ...    67230    6000    61230    -61970   224188.0
# 2449  451.0       -  ...   276000  335000   -59000  -1739234   673000.0
# 2450  446.0       -  ...   134300  258000  -123700   1168332  1414000.0
# 2451  448.5       +  ...   105000  347000  -242000    539790   892394.0
#
#         自營商賣出股數  三大法人買賣超股數    本益比  股價淨值比   殖利率
# 0     1650000.0   15108173  16.54   3.83  3.01
# 1     2579000.0   14298188  16.78   3.88  2.97
# 2     1156000.0    9042611  16.86   3.90  2.96
# 3     1321000.0   -1511300  16.69   3.86  2.99
# 4      829000.0    1034826  16.56   3.83  3.01
# ...         ...        ...    ...    ...   ...
# 2447   469104.0   -1168837  13.35   4.32  2.41
# 2448   286158.0     753909  13.36   4.33  2.41
# 2449  2412234.0  -17427683  13.19   4.27  2.44
# 2450   245668.0   -4854205  13.04   4.22  2.47
# 2451   352604.0     132141  13.11   4.25  2.45
#
# [2452 rows x 24 columns]

# %%
# define the target and features
target = ['收盤價']
features = ['成交股數', '最高價', '最低價','外資買賣超股數','投信買賣超股數','自營商買賣超股數','本益比','股價淨值比','殖利率']

# %%
df = stock_data[features + target]
df
# Out:
#           成交股數    最高價    最低價     外資買賣超股數  投信買賣超股數  自營商買賣超股數    本益比  股價淨值比  \
# 0     40647121   99.9   97.1  13859173.0  1599000   -350000  16.54   3.83
# 1     44335846  102.0  100.0  14955188.0   410000  -1067000  16.78   3.88
# 2     39502577  101.5  100.0   9244611.0    44000   -246000  16.86   3.90
# 3     42328657  101.0   99.1   -339300.0  -722000   -450000  16.69   3.86
# 4     31218717  100.0   98.9   1540826.0  -426000    -80000  16.56   3.83
# ...        ...    ...    ...         ...      ...       ...    ...    ...
# 2447   9152790  457.0  453.5  -1037654.0   -69028    -62155  13.35   4.32
# 2448  10486219  462.5  457.0    754649.0    61230    -61970  13.36   4.33
# 2449  34823492  452.0  446.0 -15629449.0   -59000  -1739234  13.19   4.27
# 2450  25596357  449.5  442.5  -5898837.0  -123700   1168332  13.04   4.22
# 2451  22297604  456.5  448.5   -165649.0  -242000    539790  13.11   4.25
#
#        殖利率    收盤價
# 0     3.01   99.6
# 1     2.97  101.0
# 2     2.96  101.5
# 3     2.99  100.5
# 4     3.01   99.7
# ...    ...    ...
# 2447  2.41  456.5
# 2448  2.41  457.0
# 2449  2.44  451.0
# 2450  2.47  446.0
# 2451  2.45  448.5
#
# [2452 rows x 10 columns]

# %%
# split the data
split = int(df.shape[0] * 0.8)
df_train = df.iloc[:split, :].copy()
df_test = df.iloc[split:, :].copy()

# %%
df_train
# Out:
#           成交股數    最高價    最低價     外資買賣超股數  投信買賣超股數  自營商買賣超股數    本益比  股價淨值比  \
# 0     40647121   99.9   97.1  13859173.0  1599000   -350000  16.54   3.83
# 1     44335846  102.0  100.0  14955188.0   410000  -1067000  16.78   3.88
# 2     39502577  101.5  100.0   9244611.0    44000   -246000  16.86   3.90
# 3     42328657  101.0   99.1   -339300.0  -722000   -450000  16.69   3.86
# 4     31218717  100.0   98.9   1540826.0  -426000    -80000  16.56   3.83
# ...        ...    ...    ...         ...      ...       ...    ...    ...
# 1956  15218008  512.0  508.0   2236412.0    25970    266765  26.93   7.40
# 1957  12581145  515.0  510.0   3490555.0  -420000    578690  26.98   7.41
# 1958  39978821  485.5  475.0   5428881.0    26000    557170  27.19   7.47
# 1959  20226736  517.0  513.0   4252779.0   -88180  -1276000  27.19   7.47
# 1960  46705107  525.0  514.0  15638945.0   257000   2340998  27.72   7.62
#
#        殖利率    收盤價
# 0     3.01   99.6
# 1     2.97  101.0
# 2     2.96  101.5
# 3     2.99  100.5
# 4     3.01   99.7
# ...    ...    ...
# 1956  1.86  510.0
# 1957  1.86  511.0
# 1958  1.84  475.0
# 1959  1.84  515.0
# 1960  1.81  525.0
#
# [1961 rows x 10 columns]

# %%
df_test
# Out:
#           成交股數    最高價    最低價     外資買賣超股數  投信買賣超股數  自營商買賣超股數    本益比  股價淨值比  \
# 1961  31173332  530.0  524.0   4607817.0   419000    145827  27.98   7.69
# 1962  39489959  540.0  528.0  12463306.0   -32890    865012  28.30   7.78
# 1963  34839391  542.0  535.0   3016404.0   178430   -450512  28.62   7.86
# 1964  55614434  555.0  541.0   5149667.0   105000  -4162805  28.99   7.96
# 1965  53392763  570.0  553.0   1499379.0   -75040   2060204  29.83   8.20
# ...        ...    ...    ...         ...      ...       ...    ...    ...
# 2447   9152790  457.0  453.5  -1037654.0   -69028    -62155  13.35   4.32
# 2448  10486219  462.5  457.0    754649.0    61230    -61970  13.36   4.33
# 2449  34823492  452.0  446.0 -15629449.0   -59000  -1739234  13.19   4.27
# 2450  25596357  449.5  442.5  -5898837.0  -123700   1168332  13.04   4.22
# 2451  22297604  456.5  448.5   -165649.0  -242000    539790  13.11   4.25
#
#        殖利率    收盤價
# 1961  1.79  530.0
# 1962  1.77  536.0
# 1963  1.75  542.0
# 1964  1.73  549.0
# 1965  1.68  565.0
# ...    ...    ...
# 2447  2.41  456.5
# 2448  2.41  457.0
# 2449  2.44  451.0
# 2450  2.47  446.0
# 2451  2.45  448.5
#
# [491 rows x 10 columns]

# %%
# scale the data
target_scaler = MinMaxScaler().fit(df_train[target])
df_train[target] = target_scaler.transform(df_train[target])
df_test[target] = target_scaler.transform(df_test[target])

features_scaler = MinMaxScaler().fit(df_train[features])
df_train[features] = features_scaler.transform(df_train[features])
df_test[features] = features_scaler.transform(df_test[features])

# %%
df_train
# Out:
#           成交股數       最高價       最低價   外資買賣超股數   投信買賣超股數  自營商買賣超股數       本益比  \
# 0     0.229231  0.011625  0.009834  0.585105  0.644491  0.424735  0.378075
# 1     0.250850  0.016508  0.016624  0.591171  0.513095  0.382689  0.390909
# 2     0.222522  0.015345  0.016624  0.559563  0.472649  0.430833  0.395187
# 3     0.239086  0.014183  0.014517  0.506515  0.387999  0.418871  0.386096
# 4     0.173972  0.011858  0.014048  0.516922  0.420709  0.440568  0.379144
# ...        ...       ...       ...       ...       ...       ...       ...
# 1956  0.080193  0.969774  0.971904  0.520772  0.470656  0.460902  0.933690
# 1957  0.064739  0.976750  0.976586  0.527714  0.421373  0.479194  0.936364
# 1958  0.225314  0.908161  0.894638  0.538442  0.470660  0.477932  0.947594
# 1959  0.109549  0.981400  0.983610  0.531933  0.458042  0.370433  0.947594
# 1960  0.264736  1.000000  0.985952  0.594956  0.496187  0.582537  0.975936
#
#          股價淨值比       殖利率       收盤價
# 0     0.213693  0.508475  0.012076
# 1     0.224066  0.491525  0.015327
# 2     0.228216  0.487288  0.016489
# 3     0.219917  0.500000  0.014166
# 4     0.213693  0.508475  0.012308
# ...        ...       ...       ...
# 1956  0.954357  0.021186  0.965165
# 1957  0.956432  0.021186  0.967487
# 1958  0.968880  0.012712  0.883883
# 1959  0.968880  0.012712  0.976777
# 1960  1.000000  0.000000  1.000000
#
# [1961 rows x 10 columns]

# %%
# extract the input sequences and output values
sequence_length = 10

X_train, y_train = [], []

for i in range(sequence_length, df_train.shape[0]):
    X_train.append(df_train[features + target].iloc[i - sequence_length: i])
    y_train.append(df_train[target].iloc[i])

X_train, y_train = np.array(X_train), np.array(y_train)

X_test, y_test = [], []

for i in range(sequence_length, df_test.shape[0]):
    X_test.append(df_test[features + target].iloc[i - sequence_length: i])
    y_test.append(df_test[target].iloc[i])

X_test, y_test = np.array(X_test), np.array(y_test)

print(X_train.shape)

print(X_test.shape)
# Out:
# (1951, 10, 10)
# (481, 10, 10)

# %%
X_train
# Out:
# array([[[0.22923054, 0.0116252 , 0.00983376, ..., 0.21369295,
#          0.50847458, 0.01207617],
#         [0.25084975, 0.01650779, 0.01662374, ..., 0.22406639,
#          0.49152542, 0.01532745],
#         [0.22252249, 0.01534527, 0.01662374, ..., 0.22821577,
#          0.48728814, 0.01648862],
#         ...,
#         [0.12576664, 0.01534527, 0.01779443, ..., 0.22406639,
#          0.49152542, 0.01532745],
#         [0.12917778, 0.01650779, 0.01662374, ..., 0.23236515,
#          0.47881356, 0.01764979],
#         [0.20208292, 0.01650779, 0.01615547, ..., 0.21991701,
#          0.5       , 0.01416628]],
#
#        [[0.25084975, 0.01650779, 0.01662374, ..., 0.22406639,
#          0.49152542, 0.01532745],
#         [0.22252249, 0.01534527, 0.01662374, ..., 0.22821577,
#          0.48728814, 0.01648862],
#         [0.23908584, 0.01418275, 0.01451651, ..., 0.21991701,
#          0.5       , 0.01416628],
#         ...,
#         [0.12917778, 0.01650779, 0.01662374, ..., 0.23236515,
#          0.47881356, 0.01764979],
#         [0.20208292, 0.01650779, 0.01615547, ..., 0.21991701,
#          0.5       , 0.01416628],
#         [0.19904248, 0.01302023, 0.01475064, ..., 0.20954357,
#          0.51271186, 0.01114724]],
#
#        [[0.22252249, 0.01534527, 0.01662374, ..., 0.22821577,
#          0.48728814, 0.01648862],
#         [0.23908584, 0.01418275, 0.01451651, ..., 0.21991701,
#          0.5       , 0.01416628],
#         [0.17397169, 0.01185771, 0.01404823, ..., 0.21369295,
#          0.50847458, 0.01230841],
#         ...,
#         [0.20208292, 0.01650779, 0.01615547, ..., 0.21991701,
#          0.5       , 0.01416628],
#         [0.19904248, 0.01302023, 0.01475064, ..., 0.20954357,
#          0.51271186, 0.01114724],
#         [0.22852238, 0.01418275, 0.01311168, ..., 0.21161826,
#          0.51271186, 0.01137947]],
#
#        ...,
#
#        [[0.17157476, 0.97209951, 0.97190354, ..., 0.94813278,
#          0.02542373, 0.9605202 ],
#         [0.24337157, 0.96512439, 0.96253805, ..., 0.93568465,
#          0.02966102, 0.95123084],
#         [0.30550512, 0.97674959, 0.96956216, ..., 0.96058091,
#          0.02118644, 0.96980957],
#         ...,
#         [0.09837869, 0.96744943, 0.96722079, ..., 0.95020747,
#          0.02542373, 0.96284255],
#         [0.08019327, 0.96977447, 0.97190354, ..., 0.95435685,
#          0.02118644, 0.96516489],
#         [0.06473891, 0.97674959, 0.97658628, ..., 0.95643154,
#          0.02118644, 0.96748723]],
#
#        [[0.24337157, 0.96512439, 0.96253805, ..., 0.93568465,
#          0.02966102, 0.95123084],
#         [0.30550512, 0.97674959, 0.96956216, ..., 0.96058091,
#          0.02118644, 0.96980957],
#         [0.2212519 , 0.97674959, 0.97190354, ..., 0.94813278,
#          0.02542373, 0.9605202 ],
#         ...,
#         [0.08019327, 0.96977447, 0.97190354, ..., 0.95435685,
#          0.02118644, 0.96516489],
#         [0.06473891, 0.97674959, 0.97658628, ..., 0.95643154,
#          0.02118644, 0.96748723],
#         [0.2253137 , 0.90816089, 0.89463826, ..., 0.96887967,
#          0.01271186, 0.88388295]],
#
#        [[0.30550512, 0.97674959, 0.96956216, ..., 0.96058091,
#          0.02118644, 0.96980957],
#         [0.2212519 , 0.97674959, 0.97190354, ..., 0.94813278,
#          0.02542373, 0.9605202 ],
#         [0.22910383, 0.96977447, 0.96956216, ..., 0.95435685,
#          0.02118644, 0.96516489],
#         ...,
#         [0.06473891, 0.97674959, 0.97658628, ..., 0.95643154,
#          0.02118644, 0.96748723],
#         [0.2253137 , 0.90816089, 0.89463826, ..., 0.96887967,
#          0.01271186, 0.88388295],
#         [0.10954888, 0.98139967, 0.9836104 , ..., 0.96887967,
#          0.01271186, 0.97677659]]])

# %%
X_test
# Out:
# array([[[ 0.17370569,  1.0116252 ,  1.00936549, ...,  1.01452282,
#          -0.00847458,  1.0116117 ],
#         [ 0.22244854,  1.03487561,  1.01873098, ...,  1.03319502,
#          -0.01694915,  1.02554575],
#         [ 0.19519206,  1.03952569,  1.03512058, ...,  1.04979253,
#          -0.02542373,  1.0394798 ],
#         ...,
#         [ 0.29931561,  1.16740293,  1.14516507, ...,  1.19709544,
#          -0.08474576,  1.1532745 ],
#         [ 0.43471666,  1.18600326,  1.17092016, ...,  1.2406639 ,
#          -0.10169492,  1.18578727],
#         [ 0.52029756,  1.16740293,  1.15687193, ...,  1.20124481,
#          -0.08898305,  1.15559684]],
#
#        [[ 0.22244854,  1.03487561,  1.01873098, ...,  1.03319502,
#          -0.01694915,  1.02554575],
#         [ 0.19519206,  1.03952569,  1.03512058, ...,  1.04979253,
#          -0.02542373,  1.0394798 ],
#         [ 0.31695233,  1.06975122,  1.04916881, ...,  1.07053942,
#          -0.03389831,  1.05573618],
#         ...,
#         [ 0.43471666,  1.18600326,  1.17092016, ...,  1.2406639 ,
#          -0.10169492,  1.18578727],
#         [ 0.52029756,  1.16740293,  1.15687193, ...,  1.20124481,
#          -0.08898305,  1.15559684],
#         [ 0.58294164,  1.23250407,  1.18965114, ...,  1.22821577,
#          -0.09745763,  1.17649791]],
#
#        [[ 0.19519206,  1.03952569,  1.03512058, ...,  1.04979253,
#          -0.02542373,  1.0394798 ],
#         [ 0.31695233,  1.06975122,  1.04916881, ...,  1.07053942,
#          -0.03389831,  1.05573618],
#         [ 0.30393136,  1.10462683,  1.07726528, ...,  1.12033195,
#          -0.05508475,  1.09289364],
#         ...,
#         [ 0.52029756,  1.16740293,  1.15687193, ...,  1.20124481,
#          -0.08898305,  1.15559684],
#         [ 0.58294164,  1.23250407,  1.18965114, ...,  1.22821577,
#          -0.09745763,  1.17649791],
#         [ 0.28632466,  1.19297838,  1.17326153, ...,  1.24688797,
#          -0.10169492,  1.19043196]],
#
#        ...,
#
#        [[ 0.19767937,  0.89653569,  0.88761414, ...,  0.36307054,
#           0.20338983,  0.89665583],
#         [ 0.14339565,  0.89886073,  0.89346757, ...,  0.36307054,
#           0.20338983,  0.89665583],
#         [ 0.29405535,  0.8744478 ,  0.87239522, ...,  0.34439834,
#           0.22457627,  0.87459359],
#         ...,
#         [ 0.14762954,  0.84538479,  0.84781082, ...,  0.31327801,
#           0.25847458,  0.83743614],
#         [ 0.04464569,  0.84189723,  0.84429876, ...,  0.3153527 ,
#           0.25423729,  0.84091965],
#         [ 0.05246077,  0.85468496,  0.85249356, ...,  0.31742739,
#           0.25423729,  0.84208082]],
#
#        [[ 0.14339565,  0.89886073,  0.89346757, ...,  0.36307054,
#           0.20338983,  0.89665583],
#         [ 0.29405535,  0.8744478 ,  0.87239522, ...,  0.34439834,
#           0.22457627,  0.87459359],
#         [ 0.13302127,  0.87096024,  0.87122454, ...,  0.33609959,
#           0.23305085,  0.86414306],
#         ...,
#         [ 0.04464569,  0.84189723,  0.84429876, ...,  0.3153527 ,
#           0.25423729,  0.84091965],
#         [ 0.05246077,  0.85468496,  0.85249356, ...,  0.31742739,
#           0.25423729,  0.84208082],
#         [ 0.19509888,  0.83027203,  0.82673847, ...,  0.30497925,
#           0.26694915,  0.82814677]],
#
#        [[ 0.29405535,  0.8744478 ,  0.87239522, ...,  0.34439834,
#           0.22457627,  0.87459359],
#         [ 0.13302127,  0.87096024,  0.87122454, ...,  0.33609959,
#           0.23305085,  0.86414306],
#         [ 0.18547454,  0.86514764,  0.84781082, ...,  0.31742739,
#           0.25      ,  0.84324199],
#         ...,
#         [ 0.05246077,  0.85468496,  0.85249356, ...,  0.31742739,
#           0.25423729,  0.84208082],
#         [ 0.19509888,  0.83027203,  0.82673847, ...,  0.30497925,
#           0.26694915,  0.82814677],
#         [ 0.14101965,  0.82445943,  0.81854367, ...,  0.29460581,
#           0.27966102,  0.81653507]]])

# %%
# build and train the model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=X_train.shape[1:]))
model.add(Dropout(0.2))
model.add(LSTM(units=100, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=200, return_sequences=False))
model.add(Dropout(0.2))
# model.add(LSTM(units=20, return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(units=60, return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(units=120, return_sequences=True))
# model.add(Dropout(0.2))
model.add(Dense(units=100))
model.add(Dense(units=25))
model.add(Dense(units=1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 50)            12200
#
#  dropout (Dropout)           (None, 10, 50)            0
#
#  lstm_1 (LSTM)               (None, 10, 100)           60400
#
#  dropout_1 (Dropout)         (None, 10, 100)           0
#
#  lstm_2 (LSTM)               (None, 200)               240800
#
#  dropout_2 (Dropout)         (None, 200)               0
#
#  dense (Dense)               (None, 100)               20100
#
#  dense_1 (Dense)             (None, 25)                2525
#
#  dense_2 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 336,051
# Trainable params: 336,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

train_history=model.fit(X_train, y_train, epochs=50, batch_size=64)

model.evaluate(X_test, y_test)

#save the model
model.save('multi_intput_LSTM_model_eps50_bsize64.h5')

# generate the test set predictions
y_pred = model.predict(X_test)
y_pred = target_scaler.inverse_transform(y_pred)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 4s 29ms/step - loss: 0.0118
# Epoch 2/50
# 31/31 [==============================] - 1s 27ms/step - loss: 0.0016
# Epoch 3/50
# 31/31 [==============================] - 1s 27ms/step - loss: 0.0013
# Epoch 4/50
# 31/31 [==============================] - 1s 28ms/step - loss: 0.0013
# Epoch 5/50
# 31/31 [==============================] - 1s 28ms/step - loss: 0.0011
# Epoch 6/50
# 31/31 [==============================] - 1s 29ms/step - loss: 9.3696e-04
# Epoch 7/50
# 31/31 [==============================] - 1s 31ms/step - loss: 7.7212e-04
# Epoch 8/50
# 31/31 [==============================] - 1s 30ms/step - loss: 8.9966e-04
# Epoch 9/50
# 31/31 [==============================] - 1s 31ms/step - loss: 8.7999e-04
# Epoch 10/50
# 31/31 [==============================] - 1s 31ms/step - loss: 7.5041e-04
# Epoch 11/50
# 31/31 [==============================] - 1s 30ms/step - loss: 7.3645e-04
# Epoch 12/50
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0010
# Epoch 13/50
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0010
# Epoch 14/50
# 31/31 [==============================] - 1s 29ms/step - loss: 6.1954e-04
# Epoch 15/50
# 31/31 [==============================] - 1s 29ms/step - loss: 7.1379e-04
# Epoch 16/50
# 31/31 [==============================] - 1s 30ms/step - loss: 7.3981e-04
# Epoch 17/50
# 31/31 [==============================] - 1s 30ms/step - loss: 6.1073e-04
# Epoch 18/50
# 31/31 [==============================] - 1s 30ms/step - loss: 5.9920e-04
# Epoch 19/50
# 31/31 [==============================] - 1s 31ms/step - loss: 6.0364e-04
# Epoch 20/50
# 31/31 [==============================] - 1s 32ms/step - loss: 6.4788e-04
# Epoch 21/50
# 31/31 [==============================] - 1s 32ms/step - loss: 6.6528e-04
# Epoch 22/50
# 31/31 [==============================] - 1s 30ms/step - loss: 6.2483e-04
# Epoch 23/50
# 31/31 [==============================] - 1s 30ms/step - loss: 5.7484e-04
# Epoch 24/50
# 31/31 [==============================] - 1s 30ms/step - loss: 5.5978e-04
# Epoch 25/50
# 31/31 [==============================] - 1s 29ms/step - loss: 6.1902e-04
# Epoch 26/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.9875e-04
# Epoch 27/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.6305e-04
# Epoch 28/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.9982e-04
# Epoch 29/50
# 31/31 [==============================] - 1s 29ms/step - loss: 5.6717e-04
# Epoch 30/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.8065e-04
# Epoch 31/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.8068e-04
# Epoch 32/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.7773e-04
# Epoch 33/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.0106e-04
# Epoch 34/50
# 31/31 [==============================] - 1s 28ms/step - loss: 7.1275e-04
# Epoch 35/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.8690e-04
# Epoch 36/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.5167e-04
# Epoch 37/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.7522e-04
# Epoch 38/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.2628e-04
# Epoch 39/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.0963e-04
# Epoch 40/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.2825e-04
# Epoch 41/50
# 31/31 [==============================] - 1s 28ms/step - loss: 4.6194e-04
# Epoch 42/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.2297e-04
# Epoch 43/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.6346e-04
# Epoch 44/50
# 31/31 [==============================] - 1s 30ms/step - loss: 5.0163e-04
# Epoch 45/50
# 31/31 [==============================] - 1s 28ms/step - loss: 5.3238e-04
# Epoch 46/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.1995e-04
# Epoch 47/50
# 31/31 [==============================] - 1s 29ms/step - loss: 3.7287e-04
# Epoch 48/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.4587e-04
# Epoch 49/50
# 31/31 [==============================] - 1s 29ms/step - loss: 4.6026e-04
# Epoch 50/50
# 31/31 [==============================] - 1s 29ms/step - loss: 6.1707e-04
# 16/16 [==============================] - 1s 5ms/step - loss: 0.0028
# 16/16 [==============================] - 1s 5ms/step

# %%
# import matplotlib.pyplot as plt
# train_history.history
# plt.plot(train_history.history["loss"])
# # plt.plot(train_history.history["val_loss"])
# plt.title("Train History")
# plt.ylabel("loss")
# plt.xlabel("Epoch")
# plt.legend(['train','validation'],loc='upper left')
# # plt.show()

# %%
# plot the test set predictions
df['Predicted Close'] = np.nan
df['Predicted Close'].iloc[- y_pred.shape[0]:] = y_pred.flatten()
plot=df[['收盤價', 'Predicted Close']].plot()
fig = plot.get_figure()
fig.savefig("multi_intput_LSTM_model_eps32_bsize64.png")
# Out:
# C:\Users\mikai\AppData\Local\Temp\ipykernel_19184\895973735.py:6: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   fig.savefig("multi_intput_LSTM_model_eps32_bsize64.png")
# C:\Users\mikai\AppData\Local\Temp\ipykernel_19184\895973735.py:6: UserWarning: Glyph 30436 (\N{CJK UNIFIED IDEOGRAPH-76E4}) missing from current font.
#   fig.savefig("multi_intput_LSTM_model_eps32_bsize64.png")
# C:\Users\mikai\AppData\Local\Temp\ipykernel_19184\895973735.py:6: UserWarning: Glyph 20729 (\N{CJK UNIFIED IDEOGRAPH-50F9}) missing from current font.
#   fig.savefig("multi_intput_LSTM_model_eps32_bsize64.png")
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 30436 (\N{CJK UNIFIED IDEOGRAPH-76E4}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 20729 (\N{CJK UNIFIED IDEOGRAPH-50F9}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30436 (\N{CJK UNIFIED IDEOGRAPH-76E4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20729 (\N{CJK UNIFIED IDEOGRAPH-50F9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
res=pd.concat([stock_data['DateTime'],df],axis=1)
res
# Out:
#         DateTime      成交股數    最高價    最低價     外資買賣超股數  投信買賣超股數  自營商買賣超股數  \
# 0     2013-01-02  40647121   99.9   97.1  13859173.0  1599000   -350000
# 1     2013-01-03  44335846  102.0  100.0  14955188.0   410000  -1067000
# 2     2013-01-04  39502577  101.5  100.0   9244611.0    44000   -246000
# 3     2013-01-07  42328657  101.0   99.1   -339300.0  -722000   -450000
# 4     2013-01-08  31218717  100.0   98.9   1540826.0  -426000    -80000
# ...          ...       ...    ...    ...         ...      ...       ...
# 2447  2022-12-26   9152790  457.0  453.5  -1037654.0   -69028    -62155
# 2448  2022-12-27  10486219  462.5  457.0    754649.0    61230    -61970
# 2449  2022-12-28  34823492  452.0  446.0 -15629449.0   -59000  -1739234
# 2450  2022-12-29  25596357  449.5  442.5  -5898837.0  -123700   1168332
# 2451  2022-12-30  22297604  456.5  448.5   -165649.0  -242000    539790
#
#         本益比  股價淨值比   殖利率    收盤價  Predicted Close
# 0     16.54   3.83  3.01   99.6              NaN
# 1     16.78   3.88  2.97  101.0              NaN
# 2     16.86   3.90  2.96  101.5              NaN
# 3     16.69   3.86  2.99  100.5              NaN
# 4     16.56   3.83  3.01   99.7              NaN
# ...     ...    ...   ...    ...              ...
# 2447  13.35   4.32  2.41  456.5       490.651154
# 2448  13.36   4.33  2.41  457.0       488.122009
# 2449  13.19   4.27  2.44  451.0       485.876923
# 2450  13.04   4.22  2.47  446.0       483.357452
# 2451  13.11   4.25  2.45  448.5       480.511322
#
# [2452 rows x 12 columns]

# %%
dfpred=res[['DateTime','收盤價', 'Predicted Close']].dropna()
dfpred
# Out:
#         DateTime    收盤價  Predicted Close
# 1971  2021-01-15  601.0       570.048462
# 1972  2021-01-18  607.0       575.196045
# 1973  2021-01-19  627.0       579.699158
# 1974  2021-01-20  647.0       584.532654
# 1975  2021-01-21  673.0       589.738159
# ...          ...    ...              ...
# 2447  2022-12-26  456.5       490.651154
# 2448  2022-12-27  457.0       488.122009
# 2449  2022-12-28  451.0       485.876923
# 2450  2022-12-29  446.0       483.357452
# 2451  2022-12-30  448.5       480.511322
#
# [481 rows x 3 columns]

# %%
dfpred.plot(x='DateTime')
# Out:
# <AxesSubplot: xlabel='DateTime'>
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 30436 (\N{CJK UNIFIED IDEOGRAPH-76E4}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 20729 (\N{CJK UNIFIED IDEOGRAPH-50F9}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25910 (\N{CJK UNIFIED IDEOGRAPH-6536}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30436 (\N{CJK UNIFIED IDEOGRAPH-76E4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mikai\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20729 (\N{CJK UNIFIED IDEOGRAPH-50F9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
